# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
d = pd.read_csv('dane.csv')
d.info()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df1 = d[d.isna().any(axis=1)]
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   identyfikator                380 non-null    int64
#  1   powiat                       380 non-null    object
#  2   populacja_ogolem             380 non-null    int64
#  3   populacja_produkcyjna        380 non-null    int64
#  4   stadiony                     380 non-null    int64
#  5   hale_sportowe                380 non-null    int64
#  6   sale_gimnastyczne            380 non-null    int64
#  7   korty_tenisowe               380 non-null    int64
#  8   plywalnie                    380 non-null    int64
#  9   wodociagi                    380 non-null    int64
#  10  drogi_utwardzone_na_obszar   380 non-null    float64
#  11  drogi_utwardzone_na_ludnosc  380 non-null    float64
#  12  drogi_gruntowe_na_obszar     380 non-null    float64
# ...

# %%
d[d['identyfikator'] == 331]
# Out:
#      identyfikator          powiat  populacja_ogolem  populacja_produkcyjna  \
# 330            331  Powiat kaliski             82911                  50642
#
#      stadiony  hale_sportowe  sale_gimnastyczne  korty_tenisowe  plywalnie  \
# 330         2              2                  2               0          0
#
#      wodociagi  drogi_utwardzone_na_obszar  drogi_utwardzone_na_ludnosc  \
# 330      78909                       114.1                        159.6
#
#      drogi_gruntowe_na_obszar  drogi_gruntowe_na_ludnosc    gaz  \
# 330                      42.4                       59.4  12454
#
#      technika_zawodowki  sciezki_rowerowe_na_obszar  \
# 330                  19                       288.8
#
#      sciezki_rowerowe_na_ludnosc  przystanki_zbiorkom  licea  kanalizacja  \
# 330                         4.04                  657      0        30033
#
#      wynagrodzenia  odbior_odpadow  koszty_odpadow  szkoly_podstawowe
# ...

# %%
# Out:
#    identyfikator           powiat  populacja_ogolem  populacja_produkcyjna  \
# 9             10  Powiat lubański             53852                  32376
#
#    stadiony  hale_sportowe  sale_gimnastyczne  korty_tenisowe  plywalnie  \
# 9         7              2                  2               4          2
#
#    wodociagi  drogi_utwardzone_na_obszar  drogi_utwardzone_na_ludnosc  \
# 9      46302                       104.2                         82.9
#
#    drogi_gruntowe_na_obszar  drogi_gruntowe_na_ludnosc    gaz  \
# 9                       9.1                        7.2  28596
#
#    technika_zawodowki  sciezki_rowerowe_na_obszar  \
# 9                  24                         0.0
#
#    sciezki_rowerowe_na_ludnosc  przystanki_zbiorkom  licea  kanalizacja  \
# 9                          0.0                  252      2        35828
#
#    wynagrodzenia  odbior_odpadow  koszty_odpadow  szkoly_podstawowe
# 9        4508.29             0.0             0.0                 20

# %%
# Out:
#       id               powiat  populacja_ogolem  populacja_produkcyjna  \
# 9     10      Powiat lubański             53852                  32376
# 162  163     Powiat siedlecki             81385                  49299
# 191  192  Powiat bieszczadzki             21489                  13485
# 221  222     Powiat kolneński             37887                  24035
# 224  225     Powiat sejneński             19689                  12011
# 227  228      Powiat suwalski             35577                  21894
# 304  305    Powiat braniewski             40776                  25482
# 330  331       Powiat kaliski             82911                  50642
#
#      stadiony  hale_sportowe  sale_gimnastyczne  korty_tenisowe  plywalnie  \
# 9           7              2                  2               4          2
# 162         1              1                  4               1          0
# 191         2              1                  0               6          2
# ...
